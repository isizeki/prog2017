# %%
a=(1, 2, 3, '100 yen')

# %%
len(a)
# Out:
# 4

# %%
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# '100 yen'

# %%
a[0]=10000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-f37bd29283dc> in <module>()
# ----> 1 a[0]=10000
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 丸かっこでまとめたものは変更不可　角括弧はリスト　丸かっこはダブル

# %%
a
# Out:
# (1, 2, 3, '100 yen')

# %%
b=list(a)

# %%
b.append(5000)
b
# Out:
# [1, 2, 3, '100 yen', 5000]

# %%
a=(10,)

# %%
len(a)
# Out:
# 1

# %%
a={1,2,3}

# %%
a.add(1000)

# %%
a
# Out:
# {1, 2, 3, 1000}

# %%
a.add(1)
a
# Out:
# {1, 2, 3, 1000}

# %%
a.add(10)
a
# Out:
# {1, 2, 3, 10, 1000}

# %%
a.add(5)
a
# Out:
# {1, 2, 3, 5, 10, 1000}

# %% [markdown]
# 波かっこでまとめたものは、セット（集合）とよばれる
# 集合だから重複しない

# %%
a={'apple','orenge'}

# %%
a.add('grape')
a
# Out:
# {'apple', 'grape', 'orenge'}

# %%
b=['apple','orenge']
b.append('grape')
b
# Out:
# ['apple', 'orenge', 'grape']

# %%
b.append('apple')

b
# Out:
# ['apple', 'orenge', 'grape', 'apple']

# %%
a
# Out:
# {'apple', 'grape', 'orenge'}

# %%
'apple'in a
# Out:
# True

# %%
'pen'in a
# Out:
# False

# %%
b=[1,2,3]

# %%
c=set(b)

# %%
c
# Out:
# {1, 2, 3}

# %%
b=[10,10,9,9,8]

# %%
len(b)
# Out:
# 5

# %%
c=set(b)
c
# Out:
# {8, 9, 10}

# %%
dic={1:'America',39:'Italy',86:'China'}
dic[39]
# Out:
# 'Italy'

# %%
dic
# Out:
# {1: 'America', 39: 'Italy', 86: 'China'}

# %%
dic[81]='Japan'
dic
# Out:
# {1: 'America', 39: 'Italy', 81: 'Japan', 86: 'China'}

# %%
dic[81]='Nippon'
dic
# Out:
# {1: 'America', 39: 'Italy', 81: 'Nippon', 86: 'China'}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-fe5f1157ca05> in <module>()
# ----> 1 print(country_code)
#
# NameError: name 'country_code' is not defined
